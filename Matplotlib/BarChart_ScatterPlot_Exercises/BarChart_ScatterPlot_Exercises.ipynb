# %% [markdown]
# ### Exercise 1: Bar Chart

# %% [markdown]
# #### Setup

# %%
# import matplotlib and pandas
from matplotlib import pyplot as plt
import pandas as pd

# load dataset
bar_data = pd.read_csv('plant_data_simplified.csv')

# %%
# display charts correctly
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5, 3)
plt.rcParams['figure.dpi'] = 75

# %% [markdown]
# 1. Run the Setup cells to load in the necessary packages and datasets. Run the cell below to inspect the `bar_data` dataset.

# %%
bar_data.head()
# Out:
#    Unnamed: 0  Time   PH  avg_plant_height  avg_lateral_spread  \
# 0           0   104  pH5             107.6                26.2
# 1           1   104  pH6             107.8                26.9
# 2           2   104  pH7              62.2                20.8
#
#    average_leaf_length  average_leaf_width  error
# 0                 13.2                 8.0   0.50
# 1                 13.8                 7.6   1.20
# 2                 10.6                 5.8   0.75

# %% [markdown]
# 2. Above the `plt.title()` code, write the code to make a bar chart of pH and average leaf width. Set the width equal to 0.8 and align to center. The code for the title and axis labels is written for you already.

# %%
## YOUR SOLUTION HERE ##
plt.bar(x = bar_data.PH, height = bar_data.average_leaf_width, width = 0.8, align = 'center')
plt.title('Effect of pH on Leaf Width')
plt.xlabel('pH')
plt.ylabel('Leaf Width (cm)')
plt.show()

# %% [markdown]
# ### Exercise 2. Add error bars

# %% [markdown]
# #### Setup

# %%
# import matplotlib and pandas
from matplotlib import pyplot as plt
import pandas as pd

# load dataset
bar_data = pd.read_csv('plant_data_simplified.csv')

# %%
# display charts correctly
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5, 3)
plt.rcParams['figure.dpi'] = 75

# %% [markdown]
# 1. Run the Setup cells to load in the necessary packages and datasets. Run the cell below to see the `bar_data` dataset again. We'll use the `error` column in this exercise.

# %%
bar_data.head()
# Out:
#    Unnamed: 0  Time   PH  avg_plant_height  avg_lateral_spread  \
# 0           0   104  pH5             107.6                26.2
# 1           1   104  pH6             107.8                26.9
# 2           2   104  pH7              62.2                20.8
#
#    average_leaf_length  average_leaf_width  error
# 0                 13.2                 8.0   0.50
# 1                 13.8                 7.6   1.20
# 2                 10.6                 5.8   0.75

# %% [markdown]
# 2. In the space above `plt.show()`, write the code to add error bars using the `error` column. Set the marker to `'o'` and make the error bar color `'orangered'`.

# %%
## YOUR SOLUTION HERE ##
plt.bar(x = bar_data.PH, height = bar_data.average_leaf_width, width = 0.8, align = 'center')
plt.title('Effect of pH on Leaf Width')
plt.xlabel('pH')
plt.ylabel('Leaf Width (cm)')
plt.errorbar(x = bar_data.PH, y = bar_data.average_leaf_width, yerr = bar_data.error, fmt = 'o', color = 'orangered')
plt.show()

# %% [markdown]
# ### Exercise 3. Scatterplot

# %% [markdown]
# #### Setup

# %%
# import matplotlib and pandas
from matplotlib import pyplot as plt
import pandas as pd

# load dataset
scatter_data = pd.read_csv('spotify_data_by_genres.csv')

# %%
# display charts correctly
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5, 3)
plt.rcParams['figure.dpi'] = 75

# %% [markdown]
# 1.  Run the Setup cells to load in the necessary packages and the `spotify_data_by_genres` csv. Run the next cell to use the `head()` function to check out the columns in the dataset to get a sense of what it contains.

# %%
scatter_data.head()
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# ...

# %% [markdown]
# 2. Write the code to make a scatterplot comparing **danceability** and **valence**. Danceability is a measure of how “danceable” a song is, from 0 (not dance-y, like an audiobook or funeral dirge) to 1 (very dance-y, like disco or house music). Valence is a measure of the song’s mood: sad to happy from 0 to 1.

# %%
## YOUR SOLUTION HERE ##
plt.scatter(scatter_data.danceability, scatter_data.valence)
plt.title('Mood and Danceability correlation in Spotify genres')
plt.xlabel('Danceability')
plt.ylabel('Valence / Mood (sadder to happier)')
plt.show()

# %% [markdown]
# 3. Adjust the `alpha` to 0.25 to make the relationship more obvious. Play around with other alpha values to see how the graph’s readability changes!

# %%
## YOUR SOLUTION HERE ##
plt.scatter(scatter_data.danceability, scatter_data.valence, alpha = 0.25)
plt.title('Mood and Danceability correlation in Spotify genres')
plt.xlabel('Danceability')
plt.ylabel('Valence / Mood (sadder to happier)')
plt.show()

# %% [markdown]
# 4. Change the `color` to ‘teal’ and the `alpha` to 0.15.

# %%
## YOUR SOLUTION HERE ##
plt.scatter(scatter_data.danceability, scatter_data.valence, color = 'teal', alpha = 0.15)
plt.title('Mood and Danceability correlation in Spotify genres')
plt.xlabel('Danceability')
plt.ylabel('Valence / Mood (sadder to happier)')
plt.show()

# %% [markdown]
# 5. Experiment with other Spotify categories in the `x` and `y` parameters, if you want!

# %%
## YOUR SOLUTION HERE ##
plt.scatter(scatter_data.popularity, scatter_data.energy, color = 'pink', alpha = 0.15)
plt.title('___ and ___ correlation in Spotify genres')
plt.xlabel('Popularity')
plt.ylabel('Energy')
plt.show()

# %% [markdown]
# ### Exercise 4: View in subplots

# %% [markdown]
# #### Setup

# %%
# import matplotlib and pandas
from matplotlib import pyplot as plt
import pandas as pd

# load dataset
scatter_data = pd.read_csv('spotify_data_by_genres.csv')
scatter_data.head()
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# ...

# %%
# display charts correctly
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['figure.dpi'] = 75

# %% [markdown]
# 1. First, run the Setup cells above to load in the necessary packages and the `spotify_data_by_genres` csv. **Our goal for this exercise is to see if any of the variables have a correlation with the `popularity` variable.** In the cell below, write the code to make a subplot grid with 3 rows and 4 columns. We won't put any graphs in the grid yet, so your code will use only the `subplot` function.

# %%
## YOUR SOLUTION HERE ##
plt.subplot(3, 4, 1)
plt.subplot(3, 4, 2)
plt.subplot(3, 4, 3)
plt.subplot(3, 4, 4)
plt.subplot(3, 4, 5)
plt.subplot(3, 4, 6)
plt.subplot(3, 4, 7)
plt.subplot(3, 4, 8)
plt.subplot(3, 4, 9)
plt.subplot(3, 4, 10)
plt.subplot(3, 4, 11)
plt.subplot(3, 4, 12)

plt.show()

# %% [markdown]
# 2. Now, add a line of code below each subplot to make a scatterplot in each square of the grid. Each scatterplot should have `popularity` as the x-variable and then the following y-variables: `acousticness`, `danceability`, `duration_ms`, `energy`, `instrumentalness`, `liveness`, `loudness`, `speechiness`, `tempo`, `valence`, `key`, and `popularity`. (Yes, the final square will plot `popularity` against itself!) Set the `alpha` equal to `0.05`.

# %%
## YOUR SOLUTION HERE ##
plt.subplot(3, 4, 1)
plt.scatter(scatter_data.popularity, scatter_data.acousticness, alpha = 0.05)
plt.subplot(3, 4, 2)
plt.scatter(scatter_data.popularity, scatter_data.danceability, alpha = 0.05)
plt.subplot(3, 4, 3)
plt.scatter(scatter_data.popularity, scatter_data.duration_ms, alpha = 0.05)
plt.subplot(3, 4, 4)
plt.scatter(scatter_data.popularity, scatter_data.energy, alpha = 0.05)
plt.subplot(3, 4, 5)
plt.scatter(scatter_data.popularity, scatter_data.instrumentalness, alpha = 0.05)
plt.subplot(3, 4, 6)
plt.scatter(scatter_data.popularity, scatter_data.liveness, alpha = 0.05)
plt.subplot(3, 4, 7)
plt.scatter(scatter_data.popularity, scatter_data.loudness, alpha = 0.05)
plt.subplot(3, 4, 8)
plt.scatter(scatter_data.popularity, scatter_data.speechiness, alpha = 0.05)
plt.subplot(3, 4, 9)
plt.scatter(scatter_data.popularity, scatter_data.tempo, alpha = 0.05)
plt.subplot(3, 4, 10)
plt.scatter(scatter_data.popularity, scatter_data.valence, alpha = 0.05)
plt.subplot(3, 4, 11)
plt.scatter(scatter_data.popularity, scatter_data.key, alpha = 0.05)
plt.subplot(3, 4, 12)
plt.scatter(scatter_data.popularity, scatter_data.popularity, alpha = 0.05)

plt.show()

# %% [markdown]
# 3. This gives us something to work with! These correlations are a bit all over the place, and  the ability to easily compare their differences is helpful. **Add a title above each graph using and instance of `plt.title()` for each subplot.**

# %%
## YOUR SOLUTION HERE ##
plt.subplot(3, 4, 1)
plt.scatter(scatter_data.popularity, scatter_data.acousticness, alpha = 0.05)
plt.title('acousticness')
plt.subplot(3, 4, 2)
plt.scatter(scatter_data.popularity, scatter_data.danceability, alpha = 0.05)
plt.title('danceability')
plt.subplot(3, 4, 3)
plt.scatter(scatter_data.popularity, scatter_data.duration_ms, alpha = 0.05)
plt.title('duration_ms')
plt.subplot(3, 4, 4)
plt.scatter(scatter_data.popularity, scatter_data.energy, alpha = 0.05)
plt.title('energy')
plt.subplot(3, 4, 5)
plt.scatter(scatter_data.popularity, scatter_data.instrumentalness, alpha = 0.05)
plt.title('instrumentalness')
plt.subplot(3, 4, 6)
plt.scatter(scatter_data.popularity, scatter_data.liveness, alpha = 0.05)
plt.title('liveness')
plt.subplot(3, 4, 7)
plt.scatter(scatter_data.popularity, scatter_data.loudness, alpha = 0.05)
plt.title('loudness')
plt.subplot(3, 4, 8)
plt.scatter(scatter_data.popularity, scatter_data.speechiness, alpha = 0.05)
plt.title('speechiness')
plt.subplot(3, 4, 9)
plt.scatter(scatter_data.popularity, scatter_data.tempo, alpha = 0.05)
plt.title('tempo')
plt.subplot(3, 4, 10)
plt.scatter(scatter_data.popularity, scatter_data.valence, alpha = 0.05)
plt.title('valence')
plt.subplot(3, 4, 11)
plt.scatter(scatter_data.popularity, scatter_data.key, alpha = 0.05)
plt.title('key')
plt.subplot(3, 4, 12)
plt.scatter(scatter_data.popularity, scatter_data.popularity, alpha = 0.05)
plt.title('popularity')

plt.subplots_adjust(hspace=0.5, wspace=0.3)
plt.show()

# %% [markdown]
# 4. Finally, we'll add our super title. Above the first subplot, add a line of code to make the super title: 'Relationship between Popularity and _______________'.

# %%
## YOUR SOLUTION HERE ##
plt.suptitle('Relationship between Popularity and ______')
plt.subplot(3, 4, 1)
plt.scatter(scatter_data.popularity, scatter_data.acousticness, alpha = 0.05)
plt.title('acousticness')
plt.subplot(3, 4, 2)
plt.scatter(scatter_data.popularity, scatter_data.danceability, alpha = 0.05)
plt.title('danceability')
plt.subplot(3, 4, 3)
plt.scatter(scatter_data.popularity, scatter_data.duration_ms, alpha = 0.05)
plt.title('duration_ms')
plt.subplot(3, 4, 4)
plt.scatter(scatter_data.popularity, scatter_data.energy, alpha = 0.05)
plt.title('energy')
plt.subplot(3, 4, 5)
plt.scatter(scatter_data.popularity, scatter_data.instrumentalness, alpha = 0.05)
plt.title('instrumentalness')
plt.subplot(3, 4, 6)
plt.scatter(scatter_data.popularity, scatter_data.liveness, alpha = 0.05)
plt.title('liveness')
plt.subplot(3, 4, 7)
plt.scatter(scatter_data.popularity, scatter_data.loudness, alpha = 0.05)
plt.title('loudness')
plt.subplot(3, 4, 8)
plt.scatter(scatter_data.popularity, scatter_data.speechiness, alpha = 0.05)
plt.title('speechiness')
plt.subplot(3, 4, 9)
plt.scatter(scatter_data.popularity, scatter_data.tempo, alpha = 0.05)
plt.title('tempo')
plt.subplot(3, 4, 10)
plt.scatter(scatter_data.popularity, scatter_data.valence, alpha = 0.05)
plt.title('valence')
plt.subplot(3, 4, 11)
plt.scatter(scatter_data.popularity, scatter_data.key, alpha = 0.05)
plt.title('key')
plt.subplot(3, 4, 12)
plt.scatter(scatter_data.popularity, scatter_data.popularity, alpha = 0.05)
plt.title('popularity')
             
plt.subplots_adjust(hspace=0.5, wspace=0.3)
plt.show()

# %% [markdown]
# ### Exercise 5: Pie Charts

# %% [markdown]
# #### Setup

# %%
# import matplotlib and pandas
from matplotlib import pyplot as plt
import pandas as pd

# load dataset
pie_data = pd.read_csv('EV_market_share.csv')

# %%
# display charts correctly
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5, 3)
plt.rcParams['figure.dpi'] = 75

# %% [markdown]
# 1. Run the Setup cells to load in the necessary packages and the `EV_market_share` csv. Run the cell below to view the columns in the `pie_data` dataset.

# %%
pie_data.head()
# Out:
#                    model  number_sold
# 0          Tesla Model Y       193454
# 1          Tesla Model 3       107932
# 2    Ford Mustang Mach-E        27140
# 3  Chevrolet Bolt EV/EUV        24828
# 4        Volkswagen ID.4        16742

# %% [markdown]
# 2. Write the code to make a pie chart of the `‘number_sold’` column.

# %%
## YOUR SOLUTION HERE ##
plt.pie(pie_data.number_sold)
plt.title('Top 10 EVs sold in the US by count, 2021')
plt.show()

# %% [markdown]
# 3. Add labels to the pie chart using the `‘model’` column of the dataset.

# %%
## YOUR SOLUTION HERE ##
plt.pie(x = pie_data.number_sold, labels = pie_data.model)
plt.title('Top 10 EVs sold in the US by count, 2021')
plt.show()

# %% [markdown]
# 4. Set the start angle equal to 60.

# %%
## YOUR SOLUTION HERE ##
plt.pie(x = pie_data.number_sold, labels = pie_data.model, startangle = 60)
plt.title('Top 10 EVs sold in the US by count, 2021')
plt.show()

# %% [markdown]
# 5. Optionally, change the colors in the chart. What happens if you only add one color? Or two? A complete list of named matplotlib colors can be found [here](https://matplotlib.org/stable/gallery/color/named_colors.html).

# %%
## YOUR SOLUTION HERE ## 
plt.pie(x = pie_data.number_sold, labels = pie_data.model, startangle = 60, colors = ['teal', 'lightgreen', 'aquamarine'])
plt.title('Top 10 EVs sold in the US by count, 2021')
plt.show()

# %% [markdown]
# ### Exercise 6: Histogram

# %% [markdown]
# #### Setup

# %%
# import matplotlib and pandas
from matplotlib import pyplot as plt
import pandas as pd

# load dataset
hist_data = pd.read_csv('lobster_dist.csv')

# %%
# display charts correctly
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5, 3)
plt.rcParams['figure.dpi'] = 75

# %% [markdown]
# 1. Run the Setup cells above. In the cell below, run the code to check out the first few rows of `hist_data` to see what we’re working with. (Note: `carapace_length` refers to the length of the lobster’s shell.)

# %%
hist_data.head()
# Out:
#    specimen  carapace_length
# 0         0               79
# 1         1               80
# 2         2               80
# 3         3               80
# 4         4               80

# %% [markdown]
# 2. Now that we've looked at some of the data in table form, let's see it as a histogram. Write the code to make a histogram. Set the `bins` to 10.

# %%
## YOUR SOLUTION HERE ##
plt.hist(x = hist_data.carapace_length, bins = 10)
plt.show()

# %% [markdown]
# 3. Change the number of `bins` to 20. Let's also make this graph more readable: **title** the graph "Lobsters tagged by size", and **label** the x and y axes "Carapace length (mm)" and "Number tagged", respectively.

# %%
## YOUR SOLUTION HERE ##
plt.hist(x = hist_data.carapace_length, bins = 20)
plt.title('Lobsters tagged by size')
plt.xlabel('Carapace length (mm)')
plt.ylabel('Number tagged')
plt.show()

# %% [markdown]
# 4. Set the `bins` equal to 30. Let's give the distribution a little breathing room on either side by specifying a `range` of `(75, 155)` - just slightly outside of our minimum and maximum x-values. Additionally, set the histogram `color` to `'gold'`... because why not?

# %%
## YOUR SOLUTION HERE ##
plt.hist(x = hist_data.carapace_length, bins = 30, range = (75, 155), color = 'gold')
plt.title('Lobsters tagged by size')
plt.xlabel('Carapace length (mm)')
plt.ylabel('Number tagged')
plt.show()

# %% [markdown]
# 5. OPTIONAL: Play around with the number of bins. How many bins is too many? How many is too few? At what number does the graph appear as just one peak (unimodal distribution) rather than two peaks (bimodal distribution)?

# %%
## YOUR SOLUTION HERE ##
plt.hist(x = hist_data.carapace_length, bins = 50, range = (75, 155), color = 'teal')
plt.title('Lobsters tagged by size')
plt.xlabel('Carapace length (mm)')
plt.ylabel('Number tagged')
plt.show()

# %% [markdown]
# ### Exercise 7: Add AB lines

# %% [markdown]
# #### Setup

# %%
# import matplotlib and pandas
from matplotlib import pyplot as plt
import pandas as pd

# load dataset
hist_data = pd.read_csv('lobster_dist.csv')

# %%
# display charts correctly
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5, 3)
plt.rcParams['figure.dpi'] = 75

# %% [markdown]
# 1. Run the Setup cells above this cell. Then, run the code below to load the histogram we made in the last exercise. Consider: where should we place the AB line(s)?

# %%
## load histogram from last exercise ##
plt.hist(hist_data.carapace_length, bins=30, range=(75,155), color='gold')
plt.title('Lobsters tagged by size')
plt.ylabel('Number tagged')
plt.xlabel('Carapace length (mm)')
plt.show()

# %% [markdown]
# 2. Let's mark the minimum and maximum legal catch sizes for lobsters: 83mm minimum, and 127mm maximum. Place one vertical AB line at each of these numbers. Set the `linewidth` to `2`, `dashes` equal to `(1,2)`, and `color` to `mediumblue`.

# %%
## YOUR SOLUTION HERE ##
plt.hist(hist_data.carapace_length, bins=30, range=(75,155), color='gold')
plt.title('Lobsters tagged by size')
plt.ylabel('Number tagged')
plt.xlabel('Carapace length (mm)')
plt.axvline(x=83, ymin=0, ymax=1, linewidth=2, dashes=(1, 2), color='mediumblue') 
plt.axvline(x=127, ymin=0, ymax=1, linewidth=2, dashes=(1, 2), color='mediumblue') 
plt.show()

# %% [markdown]
# 3. Nice! Now we can see clearly that the first peak in the population distribution happens _just_ before lobsters become too big enough to be legally caught. Interesting! Let's annotate these lines to make that connection more obvious. Add an annotation for 'Minimum legal catch size' to the line at `x = 84mm` and `y = 23` and 'Maximum legal catch size' at `x = 128mm` and `y = 7`.

# %%
## YOUR SOLUTION HERE ##
plt.hist(hist_data.carapace_length, bins=30, range=(75,155), color='gold')
plt.title('Lobsters tagged by size')
plt.ylabel('Number tagged')
plt.xlabel('Carapace length (mm)')
plt.axline((83, 0), (83, 1), linewidth=2, dashes=(1,2), color='mediumblue')
plt.axline((127, 0), (127, 1), linewidth=2, dashes=(1,2), color='mediumblue')
plt.annotate('Minimum legal catch size', (84, 23), color='mediumblue')
plt.annotate('Maximum legal catch size', (128, 7), color='mediumblue')
plt.show()

# %% [markdown]
# 4. So close! Let's fix up the spacing on the second annotation to keep the graph tidy. Split the ‘Maximum legal catch size’ annotation into two lines using a line break, \n, instead of the space between the words ‘legal’ and ‘catch’.

# %%
## YOUR SOLUTION HERE ##
plt.hist(hist_data.carapace_length, bins=30, range=(75,155), color='gold')
plt.title('Lobsters tagged by size')
plt.ylabel('Number tagged')
plt.xlabel('Carapace length (mm)')
plt.axline((83, 0), (83, 1), linewidth=2, dashes=(1,2), color='mediumblue')
plt.axline((127, 0), (127, 1), linewidth=2, dashes=(1,2), color='mediumblue')
plt.annotate('Minimum legal catch size', (84, 23), color='mediumblue')
plt.annotate('Maximum legal\ncatch size', (128, 7), color='mediumblue')
plt.show()
